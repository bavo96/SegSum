# %%
# %matplotlib ipympl 
# Pip install ipympl
from mpl_toolkits.mplot3d import Axes3D 
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np

def loss_func(x, y, sigma):
    loss = np.abs((x + y)/ 2 - sigma)
    return loss

# %%
# Data for a three-dimensional line
y1 = np.linspace(0., 1., 30)
y2 = np.linspace(0., 1., 30)
print(y1, y2)
X, Y = np.meshgrid(y1, y2)
print(X[1])
print(Y[1])
Z = loss_func(X, Y, sigma=0.15)
print(Z[1])
 

ax = plt.axes(projection='3d')
# ax.plot_wireframe(X, Y, Z, rstride=10, cstride=10)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='viridis', edgecolor='none')
plt.show()
# Out:
# [0.         0.03448276 0.06896552 0.10344828 0.13793103 0.17241379
#  0.20689655 0.24137931 0.27586207 0.31034483 0.34482759 0.37931034
#  0.4137931  0.44827586 0.48275862 0.51724138 0.55172414 0.5862069
#  0.62068966 0.65517241 0.68965517 0.72413793 0.75862069 0.79310345
#  0.82758621 0.86206897 0.89655172 0.93103448 0.96551724 1.        ] [0.         0.03448276 0.06896552 0.10344828 0.13793103 0.17241379
#  0.20689655 0.24137931 0.27586207 0.31034483 0.34482759 0.37931034
#  0.4137931  0.44827586 0.48275862 0.51724138 0.55172414 0.5862069
#  0.62068966 0.65517241 0.68965517 0.72413793 0.75862069 0.79310345
#  0.82758621 0.86206897 0.89655172 0.93103448 0.96551724 1.        ]
# [0.         0.03448276 0.06896552 0.10344828 0.13793103 0.17241379
#  0.20689655 0.24137931 0.27586207 0.31034483 0.34482759 0.37931034
#  0.4137931  0.44827586 0.48275862 0.51724138 0.55172414 0.5862069
#  0.62068966 0.65517241 0.68965517 0.72413793 0.75862069 0.79310345
#  0.82758621 0.86206897 0.89655172 0.93103448 0.96551724 1.        ]
# [0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276
#  0.03448276 0.03448276 0.03448276 0.03448276 0.03448276 0.03448276]
# [0.13275862 0.11551724 0.09827586 0.08103448 0.0637931  0.04655172
#  0.02931034 0.01206897 0.00517241 0.02241379 0.03965517 0.05689655
#  0.07413793 0.09137931 0.10862069 0.12586207 0.14310345 0.16034483
#  0.17758621 0.19482759 0.21206897 0.22931034 0.24655172 0.2637931
#  0.28103448 0.29827586 0.31551724 0.33275862 0.35       0.36724138]
